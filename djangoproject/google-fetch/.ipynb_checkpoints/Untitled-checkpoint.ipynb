# %%
from seleniumwire import webdriver
from webdriver_manager.chrome import ChromeDriverManager

def interceptor(request):
    # del request.headers
    request.headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36",
        "Accept-Language": "en-US,en;q=0.9",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
        "Accept-Encoding": "gzip, deflate, br", "upgrade-insecure-requests": "1"
    }

# def clean_interceptor(request):
#     del request.headers

options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--allow-insecure-localhost')
options.add_argument("--incognito")
options.add_argument("--incognito")

# add acceptInsecureCerts
capabilities = options.to_capabilities()
capabilities['acceptInsecureCerts'] = True

proxy_options = {
#     'proxy': {
#         'http': "http://scrapingdog:649c53e10a13b35c882b97ce-country=us@proxy.scrapingdog.com:8081",
#         'https': "https://scrapingdog:649c53e10a13b35c882b97ce-country=us@proxy.scrapingdog.com:8081",
#     }
}
driver = webdriver.Chrome(options=options, seleniumwire_options=proxy_options)

## Send Request Using Proxy
print(driver.get('http://httpbin.org/ip'))
driver.request_interceptor = interceptor
page = driver.get(f'https://mekan.com/yeme-icme/c/istanbul/i/kadikoy/o/bar?p=1')
# Out:
# None

# %%
resp = driver.page_source
from bs4 import BeautifulSoup
soup = BeautifulSoup(resp, 'html.parser')

# %%
total_page_number = int(soup.find('ul', {"class": "pagination"}).find_all('li')[-1].text)
current_page = int(soup.find('ul', {"class": "pagination"}).find_all('li',{"class": "selected active"})[0].text)
list_of_cities=[item['value'].replace('https://mekan.com/yeme-icme/c/','').replace('/o/bar','') for item in soup.find('select',{"id": "city"}).find_all('option') if '/c/' in item['value']]

# %%
page = driver.get(f'https://mekan.com/yeme-icme/c/istanbul/i/adalar/o/bar?p=1')

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
ilce_list = [item['value'].replace(f'https://mekan.com/yeme-icme/c/{il}/i/','').replace('/o/bar','') for item in soup.find('select',{"id": "town"}).find_all('option')  if '/i/' in item['value']]
print(list_of_cities)
print(ilce_list)
# Out:
# ['istanbul', 'ankara', 'izmir', 'bursa', 'canakkale', 'eskisehir', 'gaziantep', 'hatay', 'mugla']
# ['adalar', 'arnavutkoy', 'atasehir', 'avcilar', 'bagcilar', 'bahcelievler', 'bakirkoy', 'basaksehir', 'bayrampasa', 'besiktas', 'beykoz', 'beylikduzu', 'beyoglu', 'buyukcekmece', 'catalca', 'cekmekoy', 'esenler', 'esenyurt', 'eyup', 'fatih', 'gaziosmanpasa', 'gungoren', 'kadikoy', 'kagithane', 'kartal', 'kucukcekmece', 'maltepe', 'pendik', 'sancaktepe', 'sariyer', 'sile', 'silivri', 'sisli', 'sultanbeyli', 'sultangazi', 'tuzla', 'umraniye', 'uskudar', 'zeytinburnu']

# %%
try:
    print(1)
    total_page_number = int(soup.find('ul', {"class": "pagination"}).find_all('li')[-1].text)
except Exception as e:
    try:
        print(2)
        total_page_number = int(soup.find('ul', {"class": "pagination"}).find_all('li')[-3].text)
        print(total_page_number)
    except Exception as e:
        total_page_number = -1
        print(3)
print(total_page_number)
# Out:
# 1
# 3

# %%
import time
import pandas as pd
import numpy as np

for il in list_of_cities:
    for tip in ['bar','cafe']:
    
        page = driver.get(f'https://mekan.com/yeme-icme/c/{il}/')
        time.sleep(2)
        resp = driver.page_source
        soup = BeautifulSoup(resp, 'html.parser')
        ilce_list = [item['value'].replace(f'https://mekan.com/yeme-icme/c/{il}/i/','').replace(f'/o/{tip}','') for item in soup.find('select',{"id": "town"}).find_all('option')  if '/i/' in item['value']]
    #     ilce_list=['kadikoy']

        for ilce in ilce_list:
            mekan_isimleri = []
            mekan_linkleri = []
            mekan_sehirleri = []
            mekan_sokak_adresleri = []
            mekan_ratingleri = []

            page_number = 1
            total_page_number = 10

            while True:
                if (page_number > total_page_number):
                    break
                print(page_number,total_page_number)
                print(f'https://mekan.com/yeme-icme/c/{il}/i/{ilce}/o/{tip}?p={page_number}')
                page = driver.get(f'https://mekan.com/yeme-icme/c/{il}/i/{ilce}/o/{tip}?p={page_number}')
                resp = driver.page_source
                soup = BeautifulSoup(resp, 'html.parser')
                time.sleep(4)


                try:
                    print(1)
                    total_page_number = int(soup.find('ul', {"class": "pagination"}).find_all('li')[-1].text)
                except Exception as e:
                    try:
                        print(2)
                        total_page_number = int(soup.find('ul', {"class": "pagination"}).find_all('li')[-3].text)
                        print(total_page_number)
                    except Exception as e:
                        total_page_number = -1
                        print(3)

                print(il, ilce, total_page_number)
                mekan_isimleri += [mekan.text for mekan in soup.find_all('a', {"itemprop": "name"})]
                mekan_linkleri += [mekan.href for mekan in soup.find_all('a', {"itemprop": "name"})]
                mekan_sehirleri += [mekan.text for mekan in soup.find_all('b', {"itemprop": "addressLocality"})]
                mekan_sokak_adresleri += [mekan.text for mekan in soup.find_all('span', {"itemprop": "streetAddress"})]
                mekan_ratingleri += [int(mekan['content']) for mekan in soup.find_all('meta', {"itemprop": "ratingValue"})]
                page_number += 1

            DF = pd.DataFrame(np.array([mekan_isimleri,mekan_linkleri,mekan_sehirleri,mekan_sokak_adresleri,mekan_ratingleri])).transpose()
            DF.to_csv(f'mekan_com_data_{il}_{ilce}_{tip}.csv')
# Out:
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/adalar/o/bar?p=1
# 1
# 2
# 3
# istanbul adalar -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/arnavutkoy/o/bar?p=1
# 1
# 2
# 3
# istanbul arnavutkoy -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/atasehir/o/bar?p=1
# 1
# 2
# 3
# istanbul atasehir -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/avcilar/o/bar?p=1
# 1
# 2
# 3
# istanbul avcilar -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/bagcilar/o/bar?p=1
# 1
# 2
# 3
# istanbul bagcilar -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/bahcelievler/o/bar?p=1
# 1
# 2
# 3
# istanbul bahcelievler -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/bakirkoy/o/bar?p=1
# 1
# 2
# 3
# istanbul bakirkoy -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/basaksehir/o/bar?p=1
# 1
# 2
# 3
# istanbul basaksehir -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/bayrampasa/o/bar?p=1
# 1
# 2
# 3
# istanbul bayrampasa -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/besiktas/o/bar?p=1
# 1
# istanbul besiktas 4
# 2 4
# https://mekan.com/yeme-icme/c/istanbul/i/besiktas/o/bar?p=2
# 1
# istanbul besiktas 4
# 3 4
# https://mekan.com/yeme-icme/c/istanbul/i/besiktas/o/bar?p=3
# 1
# istanbul besiktas 4
# 4 4
# https://mekan.com/yeme-icme/c/istanbul/i/besiktas/o/bar?p=4
# 1
# istanbul besiktas 4
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/beykoz/o/bar?p=1
# 1
# 2
# 3
# istanbul beykoz -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/beylikduzu/o/bar?p=1
# 1
# 2
# 3
# istanbul beylikduzu -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/beyoglu/o/bar?p=1
# 1
# 2
# 5
# istanbul beyoglu 5
# 2 5
# https://mekan.com/yeme-icme/c/istanbul/i/beyoglu/o/bar?p=2
# 1
# 2
# 6
# istanbul beyoglu 6
# 3 6
# https://mekan.com/yeme-icme/c/istanbul/i/beyoglu/o/bar?p=3
# 1
# 2
# 7
# istanbul beyoglu 7
# 4 7
# https://mekan.com/yeme-icme/c/istanbul/i/beyoglu/o/bar?p=4
# 1
# 2
# 8
# istanbul beyoglu 8
# 5 8
# https://mekan.com/yeme-icme/c/istanbul/i/beyoglu/o/bar?p=5
# 1
# 2
# 9
# istanbul beyoglu 9
# 6 9
# https://mekan.com/yeme-icme/c/istanbul/i/beyoglu/o/bar?p=6
# 1
# istanbul beyoglu 10
# 7 10
# https://mekan.com/yeme-icme/c/istanbul/i/beyoglu/o/bar?p=7
# 1
# istanbul beyoglu 10
# 8 10
# https://mekan.com/yeme-icme/c/istanbul/i/beyoglu/o/bar?p=8
# 1
# istanbul beyoglu 10
# 9 10
# https://mekan.com/yeme-icme/c/istanbul/i/beyoglu/o/bar?p=9
# 1
# istanbul beyoglu 10
# 10 10
# https://mekan.com/yeme-icme/c/istanbul/i/beyoglu/o/bar?p=10
# 1
# istanbul beyoglu 10
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/buyukcekmece/o/bar?p=1
# 1
# 2
# 3
# istanbul buyukcekmece -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/catalca/o/bar?p=1
# 1
# 2
# 3
# istanbul catalca -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/cekmekoy/o/bar?p=1
# 1
# 2
# 3
# istanbul cekmekoy -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/esenler/o/bar?p=1
# 1
# 2
# 3
# istanbul esenler -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/esenyurt/o/bar?p=1
# 1
# 2
# 3
# istanbul esenyurt -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/eyup/o/bar?p=1
# 1
# 2
# 3
# istanbul eyup -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/fatih/o/bar?p=1
# 1
# 2
# 3
# istanbul fatih -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/gaziosmanpasa/o/bar?p=1
# 1
# 2
# 3
# istanbul gaziosmanpasa -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/gungoren/o/bar?p=1
# 1
# 2
# 3
# istanbul gungoren -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/kadikoy/o/bar?p=1
# 1
# istanbul kadikoy 3
# 2 3
# https://mekan.com/yeme-icme/c/istanbul/i/kadikoy/o/bar?p=2
# 1
# istanbul kadikoy 3
# 3 3
# https://mekan.com/yeme-icme/c/istanbul/i/kadikoy/o/bar?p=3
# 1
# istanbul kadikoy 3
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/kagithane/o/bar?p=1
# 1
# 2
# 3
# istanbul kagithane -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/kartal/o/bar?p=1
# 1
# 2
# 3
# istanbul kartal -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/kucukcekmece/o/bar?p=1
# 1
# 2
# 3
# istanbul kucukcekmece -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/maltepe/o/bar?p=1
# 1
# 2
# 3
# istanbul maltepe -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/pendik/o/bar?p=1
# 1
# 2
# 3
# istanbul pendik -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/sancaktepe/o/bar?p=1
# 1
# 2
# 3
# istanbul sancaktepe -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/sariyer/o/bar?p=1
# 1
# 2
# 3
# istanbul sariyer -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/sile/o/bar?p=1
# 1
# 2
# 3
# istanbul sile -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/silivri/o/bar?p=1
# 1
# 2
# 3
# istanbul silivri -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/sisli/o/bar?p=1
# 1
# istanbul sisli 2
# 2 2
# https://mekan.com/yeme-icme/c/istanbul/i/sisli/o/bar?p=2
# 1
# istanbul sisli 2
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/sultanbeyli/o/bar?p=1
# 1
# 2
# 3
# istanbul sultanbeyli -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/sultangazi/o/bar?p=1
# 1
# 2
# 3
# istanbul sultangazi -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/tuzla/o/bar?p=1
# 1
# 2
# 3
# istanbul tuzla -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/umraniye/o/bar?p=1
# 1
# 2
# 3
# istanbul umraniye -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/uskudar/o/bar?p=1
# 1
# 2
# 3
# istanbul uskudar -1
# 1 10
# https://mekan.com/yeme-icme/c/istanbul/i/zeytinburnu/o/bar?p=1
# 1
# 2
# 3
# istanbul zeytinburnu -1

# %%
import os
import zipfile
from datetime import date

today = date.today()
zf = zipfile.ZipFile(f'{str(today)}_mekan_com_data.zip', "w")
for dirname, subdirs, files in os.walk("./"):
    zf.write(dirname)
    for filename in files:
        if('.csv' in filename):
            print(filename)
            path = os.path.join(dirname, filename)
            zf.write(path)
            os.remove(path)
zf.close()
# Out:
# mekan_com_data_istanbul_avcilar_bar.csv
# None
# mekan_com_data_istanbul_pendik_bar.csv
# None
# mekan_com_data_istanbul_uskudar_bar.csv
# None
# mekan_com_data_istanbul_esenler_bar.csv
# None
# mekan_com_data_istanbul_sancaktepe_bar.csv
# None
# mekan_com_data_istanbul_silivri_bar.csv
# None
# mekan_com_data_istanbul_umraniye_bar.csv
# None
# mekan_com_data_istanbul_bagcilar_bar.csv
# None
# mekan_com_data_istanbul_esenyurt_bar.csv
# None
# mekan_com_data_istanbul_sile_bar.csv
# None
# mekan_com_data_istanbul_tuzla_bar.csv
# None
# mekan_com_data_istanbul_beyoglu_bar.csv
# None
# mekan_com_data_istanbul_buyukcekmece_bar.csv
# None
# mekan_com_data_istanbul_kagithane_bar.csv
# None
# mekan_com_data_istanbul_sisli_bar.csv
# None
# mekan_com_data_istanbul_besiktas_bar.csv
# None
# mekan_com_data_istanbul_gaziosmanpasa_bar.csv
# None
# mekan_com_data_istanbul_sariyer_bar.csv
# None
# mekan_com_data_istanbul_beylikduzu_bar.csv
# None
# mekan_com_data_istanbul_sultangazi_bar.csv
# None
# mekan_com_data_istanbul_bahcelievler_bar.csv
# None
# mekan_com_data_istanbul_kucukcekmece_bar.csv
# None
# mekan_com_data_istanbul_eyup_bar.csv
# None
# mekan_com_data_istanbul_maltepe_bar.csv
# None
# mekan_com_data_istanbul_atasehir_bar.csv
# None
# mekan_com_data_istanbul_fatih_bar.csv
# None
# mekan_com_data_istanbul_basaksehir_bar.csv
# None
# mekan_com_data_istanbul_gungoren_bar.csv
# None
# mekan_com_data_istanbul_sultanbeyli_bar.csv
# None
# mekan_com_data_istanbul_zeytinburnu_bar.csv
# None
# mekan_com_data_istanbul_arnavutkoy_bar.csv
# None
# mekan_com_data_istanbul_beykoz_bar.csv
# None
# mekan_com_data_istanbul_kadikoy_bar.csv
# None
# mekan_com_data_istanbul_kartal_bar.csv
# None
# mekan_com_data_istanbul_catalca_bar.csv
# None
# mekan_com_data_istanbul_cekmekoy_bar.csv
# None
# mekan_com_data_istanbul_adalar_bar.csv
# None
# mekan_com_data_istanbul_bakirkoy_bar.csv
# None
# mekan_com_data_istanbul_bayrampasa_bar.csv
# None
